# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('C:/Users/JinnyeongHeo/Desktop/2022/2022-1/추천시스템/HeartDisease/archive (1)/heart_2020_cleaned.csv')
df.head()
# Out:
#   HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0           No  16.60     Yes              No     No             3.0
# 1           No  20.34      No              No    Yes             0.0
# 2           No  26.58     Yes              No     No            20.0
# 3           No  24.21      No              No     No             0.0
# 4           No  23.71      No              No     No            28.0
#
#    MentalHealth DiffWalking     Sex  AgeCategory   Race Diabetic  \
# 0          30.0          No  Female        55-59  White      Yes
# 1           0.0          No  Female  80 or older  White       No
# 2          30.0          No    Male        65-69  White      Yes
# 3           0.0          No  Female        75-79  White       No
# 4           0.0         Yes  Female        40-44  White       No
#
#   PhysicalActivity  GenHealth  SleepTime Asthma KidneyDisease SkinCancer
# 0              Yes  Very good        5.0    Yes            No        Yes
# ...

# %% [markdown]
# # 데이터 분석

# %%
df_hd = df.set_index('HeartDisease').loc['Yes']
df_nhd = df.set_index('HeartDisease').loc['No']
print(len(df_hd))
print(len(df_nhd))
# Out:
# 27373
# 292422

# %%
df_smoke = df_hd[df_hd['Smoking']=='Yes']
df_nsmoke = df_hd[df_hd['Smoking']=='No']
print(len(df_smoke))
print(len(df_smoke)/len(df_hd)*100)
print(len(df_smoke)/len(df_nhd)*100)
print(len(df_nsmoke)/len(df_nhd)*100)
# Out:
# 16037
# 58.586928725386336
# 5.484197495400482
# 3.8765893127056104

# %%
df_alcohol = df_hd[df_hd['AlcoholDrinking']=='Yes']
print(len(df_alcohol))
print(len(df_alcohol)/len(df_hd)*100)
print(len(df_alcohol)/len(df_nhd)*100)
# Out:
# 1141
# 4.168341066013955
# 0.39018952062430323

# %%
df_stroke = df_hd[df_hd['Stroke']=='Yes']
print(len(df_stroke))
print(len(df_stroke)/len(df_hd)*100)
print(len(df_stroke)/len(df_nhd)*100)
# Out:
# 4389
# 16.034048149636504
# 1.5009130639965529

# %%
df_diffWalking = df_hd[df_hd['DiffWalking']=='Yes']
print(len(df_diffWalking))
print(len(df_diffWalking)/len(df_hd)*100)
print(len(df_diffWalking)/len(df_nhd)*100)
# Out:
# 10028
# 36.63463997369671
# 3.429290545854963

# %%
df_diabetic = df_hd[df_hd['Diabetic']=='Yes']
print(len(df_diabetic))
print(len(df_diabetic)/len(df_hd)*100)
print(len(df_diabetic)/len(df_nhd)*100)
# Out:
# 8957
# 32.722025353450476
# 3.0630390326309236

# %%
df_asthma = df_hd[df_hd['Asthma']=='Yes']
print(len(df_asthma))
print(len(df_asthma)/len(df_hd)*100)
print(len(df_asthma)/len(df_nhd)*100)
# Out:
# 4933
# 18.021407956745698
# 1.6869455786500331

# %%
df_kidneyDisease = df_hd[df_hd['KidneyDisease']=='Yes']
print(len(df_kidneyDisease))
print(len(df_kidneyDisease)/len(df_hd)*100)
print(len(df_kidneyDisease)/len(df_nhd)*100)
# Out:
# 3455
# 12.621926716107112
# 1.1815116509701733

# %%
df_skinCancer = df_hd[df_hd['SkinCancer']=='Yes']
print(len(df_skinCancer))
print(len(df_skinCancer)/len(df_hd)*100)
print(len(df_skinCancer)/len(df_nhd)*100)
# Out:
# 4980
# 18.19310999890403
# 1.703018240761639

# %%
df_physicalActivity = df_hd[df_hd['PhysicalActivity']=='Yes']
print(len(df_physicalActivity))
print(len(df_physicalActivity)/len(df_hd)*100)
print(len(df_physicalActivity)/len(df_nhd)*100)
# Out:
# 17489
# 63.89142585759691
# 5.980740163188816

# %%
df.describe()['BMI']
# Out:
# count    319795.000000
# mean         28.325399
# std           6.356100
# min          12.020000
# 25%          24.030000
# 50%          27.340000
# 75%          31.420000
# max          94.850000
# Name: BMI, dtype: float64

# %%
import seaborn as sns

fig, ax = plt.subplots(figsize = (14,6))
sns.kdeplot(df[df["HeartDisease"]=='Yes']["BMI"], alpha=1,shade = False, color="#ea4335", label="Yes", ax = ax)
sns.kdeplot(df[df["HeartDisease"]=='No']["BMI"], alpha=1,shade = False, color="#4285f4", label="No", ax = ax)
ax.legend(bbox_to_anchor=(1.02, 1), loc=2, borderaxespad=0.)
plt.show()

# %%
df.describe()['PhysicalHealth']
# Out:
# count    319795.00000
# mean          3.37171
# std           7.95085
# min           0.00000
# 25%           0.00000
# 50%           0.00000
# 75%           2.00000
# max          30.00000
# Name: PhysicalHealth, dtype: float64

# %%
fig, ax = plt.subplots(figsize = (14,6))
sns.kdeplot(df[df["HeartDisease"]=='Yes']["PhysicalHealth"], alpha=1,shade = False, color="#ea4335", label="Yes", ax = ax)
sns.kdeplot(df[df["HeartDisease"]=='No']["PhysicalHealth"], alpha=1,shade = False, color="#4285f4", label="No", ax = ax)
ax.legend(bbox_to_anchor=(1.02, 1), loc=2, borderaxespad=0.)
plt.show()

# %%
df.describe()['MentalHealth']
# Out:
# count    319795.000000
# mean          3.898366
# std           7.955235
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           3.000000
# max          30.000000
# Name: MentalHealth, dtype: float64

# %%
fig, ax = plt.subplots(figsize = (14,6))
sns.kdeplot(df[df["HeartDisease"]=='Yes']["MentalHealth"], alpha=1,shade = False, color="#ea4335", label="Yes", ax = ax)
sns.kdeplot(df[df["HeartDisease"]=='No']["MentalHealth"], alpha=1,shade = False, color="#4285f4", label="No", ax = ax)
ax.legend(bbox_to_anchor=(1.02, 1), loc=2, borderaxespad=0.)
plt.show()

# %%
df.describe()['SleepTime']
# Out:
# count    319795.000000
# mean          7.097075
# std           1.436007
# min           1.000000
# 25%           6.000000
# 50%           7.000000
# 75%           8.000000
# max          24.000000
# Name: SleepTime, dtype: float64

# %%
fig, ax = plt.subplots(figsize = (14,6))
sns.kdeplot(df[df["HeartDisease"]=='Yes']["SleepTime"], alpha=1,shade = False, color="#ea4335", label="Yes", ax = ax)
sns.kdeplot(df[df["HeartDisease"]=='No']["SleepTime"], alpha=1,shade = False, color="#4285f4", label="No", ax = ax)
ax.legend(bbox_to_anchor=(1.02, 1), loc=2, borderaxespad=0.)
plt.show()

# %%
encode_AgeCategory = {'55-59':57, '80 or older':80, '65-69':67,
                      '75-79':77,'40-44':42,'70-74':72,'60-64':62,
                      '50-54':52,'45-49':47,'18-24':21,'35-39':37,
                      '30-34':32,'25-29':27}
df['AgeCategory'] = df['AgeCategory'].apply(lambda x: encode_AgeCategory[x])
df['AgeCategory'] = df['AgeCategory'].astype('float')
print(df['AgeCategory'])
# Out:
# 0         57.0
# 1         80.0
# 2         67.0
# 3         77.0
# 4         42.0
#           ...
# 319790    62.0
# 319791    37.0
# 319792    47.0
# 319793    27.0
# 319794    80.0
# Name: AgeCategory, Length: 319795, dtype: float64

# %%
fig, ax = plt.subplots(figsize = (14,6))
sns.kdeplot(df[df["HeartDisease"]=='Yes']["AgeCategory"], alpha=1,shade = False, color="#ea4335", label="HeartDisease", ax = ax)
plt.show()
